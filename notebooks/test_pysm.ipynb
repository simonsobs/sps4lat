# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
x = np.logspace(-10,3,1000)
y = (2+3*x)*np.log(((1+x)**.5 +1)/((1+x)**.5-1)) - 6*(1+x)**.5

# %%
plt.figure()
plt.plot(x,y)
plt.xlim(1e-10,1000)
plt.xscale('log')
